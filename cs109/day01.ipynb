# %% [markdown]
# ### Day 1
# #### 8/3 CS 109 Counting
#
# - originally there was early optimism with underwhelming results in 1950s to 1980s.
# - then deep blue -> stanley -> watson
# - built artificial neurons and learning by example
#
# 1. Artificial Neurons
#     1. converts inputs into a signal of some sort.
#     2. some inputs are more important. inputs -> weights -> weighted sum -> creates a probability prediction
#     3. to make a “brain”, we need many “neurons” = put lots of the things above together (inputs neurons -> hidden neurons -> output neurons)
# 2. Learn by example
#     1. basically adjusts weights given training data
#     2. Uses partials of loss relative to slider.
#
# ![Screenshot 2023-08-03 at 8.10.46 AM.png](<attachment:Screenshot 2023-08-03 at 8.10.46 AM.png>)
#
# 3. Enter gradient descent
#     1. ‘gradient of probability’ = partial
# 4. Probability is also used in aglos and sorting, hashmaps, autocomplete, recommender systems, philosophy and ethics
#
# - in probability, if there are two independent events, # of outcomes is options for 1 * options for 2
# - Complementary counting helps count complicated things through subtraction
